# %%
import importlib

# %%
import index

# %%
importlib.reload(index)
# Out:
# <module 'index' from '/Users/sri/P/InformationRetrieval/HW3/index.py'>

# %%
ir = index.index()
# Out:
# Building index
# Index built
# Calculating IDF
# Calculated IDF
# Building Vector Space
# Vector Space Built

# %% [markdown]
# ## Part B

# %%
## Query 5
p1, r1, mp1, qm1 = ir.experiment('PERSONS INVOLVED IN THE VIET NAM COUP', 7, [359, 370, 385, 397, 421])

# %%
## Query 15
query = 'AGREEMENT BY THE UNITED ARAB REPUBLIC AND SAUDI ARABIA TO WITHDRAW THEIR FORCES FROM YEMEN, WHICH INVOLVES OBSERVERS FROM THE UNITED NATIONS EXPEDITIONARY FORCE BEING SENT TO YEMEN .'
p2, r2, mp2, qm2 = ir.experiment(query, 7, [99, 100, 195, 267, 344])

# %%
## Query 40
p3, r3, mp3, qm3 = ir.experiment('RESULTS OF THE POLITICAL POLLS IN BRITAIN REGARDING WHICH PARTY IS IN THE LEAD, THE LABOR PARTY OR THE CONSERVATIVES.', 10, [20, 71,131,148,182,207,261,272,325])

# %%
ir._plot(list(range(5)), p1, p2, p3)

# %%
ir._plot(list(range(5)), r1, r2, r3)

# %%
ir._plot(list(range(5)), mp1, mp2, mp3)

# %% [markdown]
# ## Part C

# %%
## Query 5
p1, r1, mp1, qm1 = ir.top_3_feedback('PERSONS INVOLVED IN THE VIET NAM COUP')

# %%
## Query 15
query = 'AGREEMENT BY THE UNITED ARAB REPUBLIC AND SAUDI ARABIA TO WITHDRAW THEIR FORCES FROM YEMEN, WHICH INVOLVES OBSERVERS FROM THE UNITED NATIONS EXPEDITIONARY FORCE BEING SENT TO YEMEN .'
p2, r2, mp2, qm2 = ir.top_3_feedback(query)

# %%
## Query 40
p3, r3, mp3, qm3 = ir.top_3_feedback('RESULTS OF THE POLITICAL POLLS IN BRITAIN REGARDING WHICH PARTY IS IN THE LEAD, THE LABOR PARTY OR THE CONSERVATIVES.')

# %%
ir._plot(list(range(5)), p1, p2, p3)

# %%
ir._plot(list(range(5)), r1, r2, r3)

# %%
ir._plot(list(range(5)), mp1, mp2, mp3)
